# %%
import json
import os
from moviepy.editor import *
from moviepy import *
import shutil
import numpy as np

# %%
# Make sure you navigate to the github repo
# %cd video-classification-3d-cnn-pytorch/
os.getcwd()
# Out:
# [WinError 2] 系统找不到指定的文件。: 'video-classification-3d-cnn-pytorch/'
# C:\Users\wutai\SkillsClasses-main\SkillsClasses-main\01_Julian_VideoAndImageClassification\video-classification-3d-cnn-pytorch
# 'C:\\Users\\wutai\\SkillsClasses-main\\SkillsClasses-main\\01_Julian_VideoAndImageClassification\\video-classification-3d-cnn-pytorch'

# %%
# this function loads all films in the folder given as argument into the 'input' file (make sure you are in the right
# directory)

def loadVideosToInfile(folder):
    videos = os.listdir(folder)
    with open('input', 'w') as inputfile:
        for v in videos:
            if v.split('.')[-1] == 'mp4':
                inputfile.write(v+'\n')

# %%
# This function should read all .json files in the output folder, and combine them into one large dictionary
def readAllOutput(outputFolder):
    # create an empty dictionary called 'dictionaries' to which you add the dictionary entries read 
    # from the output files
    dictionaries = {}
    
    # Read all output file names to a variable output_files (a list that contains all file names)
    output_files = os.listdir(outputFolder)
    
    # Start of the for loop to loop through all files, read them, and add their contents to 'dictionaries'
    for f in output_files:
        # first test if the file extension is a '.json file'
        if f.endswith('.json'):    
            # if it is a json file, we open the file
            file_path = os.path.join(outputFolder, f)
            with open(file_path,'r',encoding='utf-8') as file:
                # Then load the file content to a variable called 'segments' with the json library
                segments = json.load(file)
                # another for loop, to add the content of segments to dictionaries. As a key use the moviename.
                for s in segments:
                    dictionaries[s['video']] = s
    
    return dictionaries

# %%
# here keyFilmName is the name of the film that you want to find a match for, and the feature dictionary is 
# the dictionary that is given as output by the readAllOutput function

def searchForMatch(keyFilmName, featureDictionary):
    # create variables to keep track of the best clips
    bestRangeStart = 0
    bestRangeFilmName = ''
    bestRangeScore = 1000000000
    
    # first read the features of the keyFilm into keyFeatures
    keyClips = featureDictionary[keyFilmName]['clips']
    keyFeatures = []
    bestMatches = []
    for c in keyClips:
        keyFeatures.append(np.array(c['features']))
    
    # now enter a for loop to go through all films, and see what the best matching sequence is 
    # (we make sure not to check the keyFilm itself by checking it's not that filename)
    for film in featureDictionary.keys():
        if not film == keyFilmName:
            
            # so now here 'film' is a filename (which is the key in the feature dictionary of that film)
            # first load the features in a 'filmFeatures' list like we did for key Features
            # then look at the provided code from the lecture to see how to iterate through the other
            # list of features to find the best segment. Now just make sure to also register what film
            # name the best matching segment is from. 
            filmClips = featureDictionary[film]['clips']
            filmFeatures = []
            filmFeatures = [np.array(s['features']) for s in filmClips]
            for i in range(len(filmFeatures)-len(keyFeatures)):
                distance = 0
                for j in range(len(keyFeatures)):
                    d = np.linalg.norm(filmFeatures[i+j]-keyFeatures[j])
                    distance += d
                if distance < bestRangeScore:
                    bestRangeScore = distance
                    bestRangeStart = i
                    bestRangeFilmName = film

                bestMatches.append({
                'bestRangeFilmName': film,
                'bestRangeStart': i,
                'bestRangeScore': distance,
                })
            
    # create a list containing the filename, start and nr of clips
    bestMatches.sort(key=lambda x: x['bestRangeScore'])
    print(bestMatches)
    bestMatches = bestMatches[0]
    
    bestRangeFilmName = bestMatches['bestRangeFilmName']
    bestRangeStart = bestMatches['bestRangeStart']
    
    matchingFragment = [bestRangeFilmName, bestRangeStart, len(keyFeatures)]
    print(matchingFragment)
    
    return matchingFragment

    # First implement it for the best matching one, then expand it to return the n best matching ones as a list,
    # with n as an argument in the function

# %%
# this is a helper function to which you give the fragment (the output of the searchForMatch function), and it returns
# a moviepy film object (which you can then save)

def extractFragment(fragment, filmFolder):
    # here adapt the code from the lecture, but make it so that it works for any input fragment list
    # the output of the function above: [bestRangeFilmName, bestRangeStart, len(keyFeatures)]
    
    filmFileName = fragment[0]
    start = fragment[1]*16 
    nrClips = fragment[2]*16
    
    film_path = os.path.join(filmFolder, filmFileName)
    film = VideoFileClip(film_path)
    tsfps = film.fps
    tsFrameLength = 1/tsfps
    
    startTime = start * tsFrameLength
    endTime = (start + nrClips) * tsFrameLength 
    
    filmFragment = film.subclip(startTime, endTime)
    
    return filmFragment

    # This function should read all .json files in the output folder, and combine them into one large dictionary

# %%
# call function to load the filenames to 'input'
loadVideosToInfile('../input_films')

# %%
# run the model to process all films currently in the input_films folder, and save it to a json file, here named by the date

# !python main.py --input input --video_root ../input_films --output ../output/output231109.json --model resnet-34-kinetics-cpu.pth --mode feature --no_cuda
# Out:
# loading model resnet-34-kinetics-cpu.pth
# ../input_films\just-sit-down-shut-up.mp4
# ../input_films\KillBill.mp4
# ../input_films\sittingMindhunter.mp4
# ffmpeg version 2023-11-05-git-44a0148fad-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 31.100 / 58. 31.100
#   libavcodec     60. 32.102 / 60. 32.102
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../input_films\just-sit-down-shut-up.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : https://clipchamp.com
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#   Duration: 00:00:10.53, start: 0.000000, bitrate: 7850 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 1280x720, 7648 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 192 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001cadefc2f00] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Create videos with https://clipchamp.com/en/video-editor - free online video editor, video compressor, video converter.
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1280x720, q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.32.102 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=4.1 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  254 fps=0.0 q=24.8 size=N/A time=00:00:08.46 bitrate=N/A speed=16.4x
# [out#0/image2 @ 000001cadb531640] video:5638kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  316 fps=0.0 q=24.8 Lsize=N/A time=00:00:10.50 bitrate=N/A speed=16.5x
# C:\Users\wutai\SkillsClasses-main\SkillsClasses-main\01_Julian_VideoAndImageClassification\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# C:\Users\wutai\SkillsClasses-main\SkillsClasses-main\01_Julian_VideoAndImageClassification\video-classification-3d-cnn-pytorch\classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# ffmpeg version 2023-11-05-git-44a0148fad-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 31.100 / 58. 31.100
#   libavcodec     60. 32.102 / 60. 32.102
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../input_films\KillBill.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Kill.Bill.2.2004.720p.BRRip.x264-x0r
#     encoder         : Lavf58.20.100
#   Duration: 00:00:21.00, start: 0.000000, bitrate: 1272 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 21.003000
#       Metadata:
#         title           : Chapter 15
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x534 [SAR 1:1 DAR 640:267], 819 kb/s, 23.98 fps, 23.98 tbr, 27093 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: ac3 (ac-3 / 0x332D6361), 48000 Hz, 5.1(side), fltp, 448 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       audio service type: main
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001eaaf48e5c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Kill.Bill.2.2004.720p.BRRip.x264-x0r
#     encoder         : Lavf60.17.100
#   Chapters:
#     Chapter #0:0: start 0.000000, end 21.003000
#       Metadata:
#         title           : Chapter 15
#   Stream #0:0(eng): Video: mjpeg, yuvj420p(pc, progressive), 1280x534 [SAR 1:1 DAR 640:267], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.32.102 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=4.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  290 fps=0.0 q=24.8 size=N/A time=00:00:12.09 bitrate=N/A speed=23.6x
# [out#0/image2 @ 000001eaac0f8ac0] video:9375kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=  503 fps=0.0 q=24.8 Lsize=N/A time=00:00:20.93 bitrate=N/A speed=23.6x
# C:\Users\wutai\SkillsClasses-main\SkillsClasses-main\01_Julian_VideoAndImageClassification\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
# ffmpeg version 2023-11-05-git-44a0148fad-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --pkg-config=pkgconf --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-dxva2 --enable-d3d11va --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58. 31.100 / 58. 31.100
#   libavcodec     60. 32.102 / 60. 32.102
#   libavformat    60. 17.100 / 60. 17.100
#   libavdevice    60.  4.100 / 60.  4.100
#   libavfilter     9. 13.100 /  9. 13.100
#   libswscale      7.  6.100 /  7.  6.100
#   libswresample   4. 13.100 /  4. 13.100
#   libpostproc    57.  4.100 / 57.  4.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../input_films\sittingMindhunter.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     creation_time   : 2022-11-15T23:49:57.000000Z
#   Duration: 00:00:02.77, start: 0.000000, bitrate: 4411 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2016 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2022-11-15T23:49:57.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: ac3 (ac-3 / 0x332D6361), 48000 Hz, 5.1(side), fltp, 448 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-15T23:49:57.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#     Side data:
#       audio service type: main
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0000016d3db9b9c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: isommp41mp42
#     encoder         : Lavf60.17.100
#   Stream #0:0(und): Video: mjpeg, yuvj420p(pc, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       creation_time   : 2022-11-15T23:49:57.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.32.102 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=5.5 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# [out#0/image2 @ 0000016d3a8f8500] video:2385kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# frame=   67 fps=0.0 q=24.8 Lsize=N/A time=00:00:02.75 bitrate=N/A speed=8.29x
# C:\Users\wutai\SkillsClasses-main\SkillsClasses-main\01_Julian_VideoAndImageClassification\video-classification-3d-cnn-pytorch\spatial_transforms.py:64: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))

# %%
# a small piece of code that moves all processed input films to the processed films folder

input_films_processed = os.listdir('../input_films')
for file in input_films_processed:
    try:
        shutil.move(os.path.join('../input_films',file),'../processed_films')
    except:
        print(file + ' not moved')

# %%
# read all output with the function declared above

dicts = readAllOutput('../output')

# %%
# look for the best matching sequence to the input file (needs to be in dicts for it to work)

fragment = searchForMatch("sittingMindhunter.mp4", dicts)
# Out:
# [{'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 4, 'bestRangeScore': 65.37810531016504}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 5, 'bestRangeScore': 66.71492512222787}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 3, 'bestRangeScore': 67.02078049969712}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 2, 'bestRangeScore': 69.5754439769172}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 6, 'bestRangeScore': 69.88520064819755}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 0, 'bestRangeScore': 70.04478778901766}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 14, 'bestRangeScore': 70.33200065581684}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 1, 'bestRangeScore': 70.48078559246804}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 12, 'bestRangeScore': 71.51595962498645}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 13, 'bestRangeScore': 71.92858366722295}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 11, 'bestRangeScore': 72.29124765516787}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 23, 'bestRangeScore': 73.49714889039707}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 10, 'bestRangeScore': 73.60420063899295}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 7, 'bestRangeScore': 74.0085703296062}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 22, 'bestRangeScore': 74.21219497904636}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 24, 'bestRangeScore': 74.59126287636921}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 6, 'bestRangeScore': 75.14961773724534}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 9, 'bestRangeScore': 75.24193326890503}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 25, 'bestRangeScore': 75.62116733954744}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 4, 'bestRangeScore': 75.84422499372828}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 9, 'bestRangeScore': 76.26094565164735}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 5, 'bestRangeScore': 76.3887313401769}, {'bestRangeFilmName': 'just-sit-down-shut-up.mp4', 'bestRangeStart': 8, 'bestRangeScore': 76.48028449252368}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 10, 'bestRangeScore': 76.52387270570213}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 8, 'bestRangeScore': 76.96076559536557}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 21, 'bestRangeScore': 77.079916145907}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 17, 'bestRangeScore': 77.43427565523633}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 11, 'bestRangeScore': 77.51242845856798}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 7, 'bestRangeScore': 77.60353757873673}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 12, 'bestRangeScore': 77.6417133280451}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 16, 'bestRangeScore': 77.77460488028078}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 13, 'bestRangeScore': 78.14270791086544}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 18, 'bestRangeScore': 78.24841857857693}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 19, 'bestRangeScore': 78.40875894811181}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 3, 'bestRangeScore': 78.80191318818864}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 26, 'bestRangeScore': 78.88331656912334}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 20, 'bestRangeScore': 78.96395982920617}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 14, 'bestRangeScore': 79.19822653389538}, {'bestRangeFilmName': 'KillBill.mp4', 'bestRangeStart': 15, 'bestRangeScore': 79.56896433057182}, {'bes ...
# ['just-sit-down-shut-up.mp4', 4, 4]

# %%
# extract the fragment from the film

fragmentFilm = extractFragment(fragment, '../processed_films')

# %%
# display the film fragment

fragmentFilm.ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# save the film fragment


fragmentFilm.write_videofile("../output_films/fragment.mp4", audio_codec='aac')
# Out:
# Moviepy - Building video ../output_films/fragment.mp4.
# MoviePy - Writing audio in fragmentTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ../output_films/fragment.mp4
# Moviepy - Done !
# Moviepy - video ready ../output_films/fragment.mp4
